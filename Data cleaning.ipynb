# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from collections import Counter

books = pd.read_csv('storygraph.csv', parse_dates = ['Date Added', 'Last Date Read'])
pd.set_option('display.max_columns', 23)

# %%
books.head()
# Out:
#                         Title             Authors Contributors       ISBN/UID  \
# 0         The Wise Man's Fear    Patrick Rothfuss          NaN  9780756404734
# 1         A Room of One's Own      Virginia Woolf          NaN  9780141183534
# 2  The Wind-Up Bird Chronicle     Haruki Murakami    Jay Rubin  9780965341981
# 3                    The Toll     Neal Shusterman          NaN  9781481497077
# 4            A Certain Hunger  Chelsea G. Summers          NaN  9781951213435
#
#       Format Read Status Date Added Last Date Read  Dates Read  Read Count  \
# 0  hardcover     to-read 2022-08-05            NaT         NaN           0
# 1  paperback     to-read 2022-08-05            NaT         NaN           0
# 2  paperback        read 2022-06-17            NaT         NaN           1
# 3  paperback        read 2022-08-02     2019-12-04  2019/12/04           1
# 4  paperback     to-read 2022-08-05            NaT         NaN           0
#
#          Moods    Pace Character- or Plot-Driven?  \
# 0          NaN     NaN                        NaN
# 1          NaN     NaN                        NaN
# 2   reflective    slow                  Character
# 3  adventurous  medium                      A mix
# 4          NaN     NaN                        NaN
#
#   Strong Character Development? Loveable Characters? Diverse Characters?  \
# 0                           NaN                  NaN                 NaN
# 1                           NaN                  NaN                 NaN
# 2                            No     It's complicated                  No
# 3                           Yes                  Yes                 Yes
# 4                           NaN                  NaN                 NaN
#
#   Flawed Characters?  Star Rating Review  Content Warnings  \
# 0                NaN          NaN    NaN               NaN
# 1                NaN          NaN    NaN               NaN
# 2   It's complicated          2.5    NaN               NaN
# 3                Yes          4.0    NaN               NaN
# 4                NaN          NaN    NaN               NaN
#
#    Content Warning Description                                     Tags Owned?
# 0                          NaN                                      NaN     No
# 1                          NaN                                      NaN     No
# 2                          NaN   mysterious, slow-paced, long, literary     No
# 3                          NaN  medium-paced, sci-fi, adventurous, long     No
# 4                          NaN                                      NaN     No

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Title                          831 non-null    object
#  1   Authors                        830 non-null    object
#  2   Contributors                   153 non-null    object
#  3   ISBN/UID                       722 non-null    object
#  4   Format                         766 non-null    object
#  5   Read Status                    831 non-null    object
#  6   Date Added                     831 non-null    datetime64[ns]
#  7   Last Date Read                 290 non-null    datetime64[ns]
#  8   Dates Read                     290 non-null    object
#  9   Read Count                     831 non-null    int64
#  10  Moods                          447 non-null    object
#  11  Pace                           450 non-null    object
#  12  Character- or Plot-Driven?     434 non-null    object
#  13  Strong Character Development?  434 non-null    object
#  14  Loveable Characters?           434 non-null    object
#  15  Diverse Characters?            434 non-null    object
#  16  Flawed Characters?             434 non-null    object
#  17  Star Rating                    451 non-null    float64
#  18  Review                         4 non-null      object
#  19  Content Warnings               0 non-null      float64
#  20  Content Warning Description    0 non-null      float64
#  21  Tags                           453 non-null    object
#  22  Owned?                         831 non-null    object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(17)
# memory usage: 94.2+ KB

# %% [markdown]
# We still need to convert 'Dates Read' to datetime. Since parse_dates failed to do so when I tried, we will do it sepparately,
# then check which value is causing the issue and if there is more than 1.

# %%
books['Dates Read'] = pd.to_datetime(books['Dates Read'], errors = 'coerce')

# %%
books['Dates Read'].notnull().sum()
# Out:
# 289

# %% [markdown]
# We need to drop some colums that aren't useful. We'll check the time interval in which books have been added, and if it's a
# short one, we can drop 'Date Added'. We'll also compare 'Last Date Read' with 'Dates Read', because they seem to be very
# similar at first glance. If they are, we'll drop one of them too.

# %%
books['Date Added'].max() - books['Date Added'].min()
# Out:
# Timedelta('53 days 00:00:00')

# %%
df = books.loc[books['Last Date Read'].notnull()]
df[['Last Date Read', 'Dates Read']]
# Out:
#     Last Date Read Dates Read
# 3       2019-12-04 2019-12-04
# 5       2022-04-10 2022-04-10
# 9       2020-03-05 2020-03-05
# 10      2020-01-20 2020-01-20
# 12      2019-01-01 2019-01-01
# ..             ...        ...
# 816     2020-06-07 2020-06-07
# 818     2020-01-18 2020-01-18
# 820     2020-03-02 2020-03-02
# 825     2019-01-01 2019-01-01
# 826     2019-01-01 2019-01-01
#
# [290 rows x 2 columns]

# %%
books.drop(['ISBN/UID', 'Format', 'Date Added', 'Dates Read', 'Read Count', 'Review', 'Content Warnings',
                     'Content Warning Description', 'Owned?'], axis=1, inplace = True)

# %% [markdown]
# Making a new dataframe with only the read books.

# %%
filt = books['Read Status'] == 'read'
read = books[filt].copy()
to_read = books[~filt]
read
# Out:
#                                Title           Authors Contributors  \
# 2         The Wind-Up Bird Chronicle   Haruki Murakami    Jay Rubin
# 3                           The Toll   Neal Shusterman          NaN
# 5               Transcendent Kingdom         Yaa Gyasi          NaN
# 9                        Hollow City      Ransom Riggs          NaN
# 10    The Astonishing Color of After    Emily X.R. Pan          NaN
# ..                               ...               ...          ...
# 820                    Truly Devious   Maureen Johnson          NaN
# 823             Domniṣoara Christina     Mircea Eliade          NaN
# 825           Into the Drowning Deep        Mira Grant          NaN
# 826  Down Among the Sticks and Bones    Seanan McGuire          NaN
# 830                   Enigma Otiliei  George Călinescu          NaN
#
#     Read Status Last Date Read        Moods    Pace  \
# 2          read            NaT   reflective    slow
# 3          read     2019-12-04  adventurous  medium
# 5          read     2022-04-10    emotional  medium
# 9          read     2020-03-05  adventurous  medium
# 10         read     2020-01-20    emotional  medium
# ..          ...            ...          ...     ...
# 820        read     2020-03-02   mysterious  medium
# 823        read            NaT   mysterious  medium
# 825        read     2019-01-01         dark  medium
# 826        read     2019-01-01         dark    fast
# 830        read            NaT    emotional    slow
#
#     Character- or Plot-Driven? Strong Character Development?  \
# 2                    Character                            No
# 3                        A mix                           Yes
# 5                    Character                           Yes
# 9                        A mix                           Yes
# 10                   Character                           Yes
# ..                         ...                           ...
# 820                       Plot                           Yes
# 823                       Plot                            No
# 825                       Plot                           Yes
# 826                      A mix                           Yes
# 830                  Character              It's complicated
#
#     Loveable Characters? Diverse Characters? Flawed Characters?  Star Rating  \
# 2       It's complicated                  No   It's complicated         2.50
# 3                    Yes                 Yes                Yes         4.00
# 5                    Yes                 Yes                Yes         4.00
# 9                    Yes                 Yes                 No         3.75
# 10                   Yes                 Yes                Yes         4.50
# ..                   ...                 ...                ...          ...
# 820     It's complicated                 Yes                Yes         3.00
# 823     It's complicated                  No                 No         4.00
# 825                  Yes                 Yes                 No         3.75
# 826                  Yes                 Yes                Yes         5.00
# 830     It's complicated                  No                Yes         3.50
#
#                                               Tags
# 2           mysterious, slow-paced, long, literary
# 3          medium-paced, sci-fi, adventurous, long
# 5        medium-paced, emotional, medium, literary
# 9       fantasy, medium-paced, adventurous, medium
# 10   medium-paced, contemporary, emotional, medium
# ..                                             ...
# 820     mysterious, thriller, medium-paced, medium
# 823      classics, mysterious, short, medium-paced
# 825             dark, medium-paced, horror, medium
# 826               fantasy, dark, short, fast-paced
# 830        classics, emotional, slow-paced, medium
#
# [463 rows x 14 columns]

# %%
read.isnull().sum()
# Out:
# Title                              0
# Authors                            1
# Contributors                     385
# Read Status                        0
# Last Date Read                   173
# Moods                             16
# Pace                              13
# Character- or Plot-Driven?        29
# Strong Character Development?     29
# Loveable Characters?              29
# Diverse Characters?               29
# Flawed Characters?                29
# Star Rating                       12
# Tags                              10
# dtype: int64

# %% [markdown]
# There are a lot of null values that need to be replaced, so we'll take a look at them and see wht we can do.

# %%
read.loc[read['Authors'].isnull()]
# Out:
#                      Title Authors                Contributors Read Status  \
# 378  The Epic of Gilgamesh     NaN  N. K. Sandars (Translator)        read
#
#     Last Date Read        Moods  Pace Character- or Plot-Driven?  \
# 378     2021-07-24  adventurous  fast                       Plot
#
#     Strong Character Development? Loveable Characters? Diverse Characters?  \
# 378                            No                   No                  No
#
#     Flawed Characters?  Star Rating                                      Tags
# 378                Yes          3.0  classics, short, adventurous, fast-paced

# %%
read['Authors'].fillna('Unknown', inplace=True)
read.loc[378, 'Authors']
# Out:
# 'Unknown'

# %%
read['Contributors'].fillna('Missing', inplace = True)
read['Contributors']
# Out:
# 2      Jay Rubin
# 3        Missing
# 5        Missing
# 9        Missing
# 10       Missing
#          ...
# 820      Missing
# 823      Missing
# 825      Missing
# 826      Missing
# 830      Missing
# Name: Contributors, Length: 463, dtype: object

# %% [markdown]
# Contributors are usually translators. In this case, we'll replace the null values with 'Missing'.

# %%
read['Last Date Read'].fillna(pd.to_datetime('2018-01-01'), inplace=True)

# %% [markdown]
# The null values in 'Last Date Read' are books read before 2019. I'll use a date in 2018 to replace the null values, because
# there is no way to guess the actual read dates for all these books and the important thing is for them to appear as read before
# 2019.

# %%
read.loc[read['Moods'].isnull()]
# Out:
#                                                  Title  \
# 68                                   The Order of Time
# 176                 Brief Answers to the Big Questions
# 203                    21 Lessons for the 21st Century
# 208                            A Brief History of Time
# 232                          The Diary of a Young Girl
# 234                                              Paula
# 276                              Beneath the Sugar Sky
# 322  The Man Who Loved Books Too Much: The True Sto...
# 385  Atomic Habits: An Easy & Proven Way to Build G...
# 424                                            My Body
# 433         I Want to Die but I Want to Eat Tteokbokki
# 452                           Man's Search for Meaning
# 464                                 Frumoasele străine
# 580                                     Milk and Honey
# 616                     Snow Flower and the Secret Fan
# 784                         We Should All Be Feminists
#
#                       Authors  \
# 68              Carlo Rovelli
# 176           Stephen Hawking
# 203         Yuval Noah Harari
# 208           Stephen Hawking
# 232                Anne Frank
# 234            Isabel Allende
# 276            Seanan McGuire
# 322   Allison Hoover Bartlett
# 385               James Clear
# 424         Emily Ratajkowski
# 433               Baek Se-hee
# 452          Viktor E. Frankl
# 464         Mircea Cărtărescu
# 580                 Rupi Kaur
# 616                  Lisa See
# 784  Chimamanda Ngozi Adichie
#
#                                           Contributors Read Status  \
# 68                                             Missing        read
# 176                                            Missing        read
# 203                                            Missing        read
# 208                                            Missing        read
# 232               B.M. Mooyaart-Doubleday (Translator)        read
# 234                              Margaret Sayers Peden        read
# 276                                            Missing        read
# 322                                            Missing        read
# 385                                            Missing        read
# 424                                            Missing        read
# 433                             Anton Hur (Translator)        read
# 452  Harold S. Kushner (Contributor), William J. Wi...        read
# 464                                            Missing        read
# 580                                            Missing        read
# 616                                            Missing        read
# 784                                            Missing        read
#
#     Last Date Read Moods    Pace Character- or Plot-Driven?  \
# 68      2022-07-18   NaN     NaN                        NaN
# 176     2019-01-01   NaN     NaN                        NaN
# 203     2022-05-31   NaN     NaN                        NaN
# 208     2020-08-30   NaN     NaN                        NaN
# 232     2018-01-01   NaN     NaN                        NaN
# 234     2018-01-01   NaN     NaN                        NaN
# 276     2019-01-01   NaN    fast                      A mix
# 322     2018-01-01   NaN     NaN                        NaN
# 385     2022-06-01   NaN     NaN                        NaN
# 424     2022-04-15   NaN     NaN                        NaN
# 433     2022-07-29   NaN     NaN                        NaN
# 452     2019-01-01   NaN     NaN                        NaN
# 464     2018-01-01   NaN  medium                      A mix
# 580     2019-01-01   NaN     NaN                        NaN
# 616     2018-01-01   NaN  medium                  Character
# 784     2022-04-13   NaN     NaN                        NaN
#
#     Strong Character Development? Loveable Characters? Diverse Characters?  \
# 68                            NaN                  NaN                 NaN
# 176                           NaN                  NaN                 NaN
# 203                           NaN                  NaN                 NaN
# 208                           NaN                  NaN                 NaN
# 232                           NaN                  NaN                 NaN
# 234                           NaN                  NaN                 NaN
# 276                           Yes                  Yes                 Yes
# 322                           NaN                  NaN                 NaN
# 385                           NaN                  NaN                 NaN
# 424                           NaN                  NaN                 NaN
# 433                           NaN                  NaN                 NaN
# 452                           NaN                  NaN                 NaN
# 464                            No     It's complicated                  No
# 580                           NaN                  NaN                 NaN
# 616                           Yes     It's complicated    It's complicated
# 784                           NaN                  NaN                 NaN
#
#     Flawed Characters?  Star Rating  \
# 68                 NaN          NaN
# 176                NaN          NaN
# 203                NaN          NaN
# 208                NaN          NaN
# 232                NaN          NaN
# 234                NaN          NaN
# 276                Yes          4.5
# 322                NaN          NaN
# 385                NaN          NaN
# 424                NaN          NaN
# 433                NaN          NaN
# 452                NaN          NaN
# 464                 No          2.0
# 580                NaN          4.0
# 616                Yes          4.0
# 784                NaN          NaN
#
#                                             Tags
# 68           informative, nonfiction, slow-paced
# 176                                          NaN
# 203                                          NaN
# 208                                          NaN
# 232                                          NaN
# 234                                          NaN
# 276      fantasy, short, adventurous, fast-paced
# 322                                          NaN
# 385                                          NaN
# 424                                          NaN
# 433         medium-paced, nonfiction, reflective
# 452                                          NaN
# 464    funny, medium-paced, contemporary, medium
# 580                            emotional, medium
# 616  medium-paced, emotional, historical, medium
# 784                                          NaN

# %%
read['Moods'].fillna('Missing', inplace=True)
read.loc[read['Moods'] == 'Missing']
# Out:
#                                                  Title  \
# 68                                   The Order of Time
# 176                 Brief Answers to the Big Questions
# 203                    21 Lessons for the 21st Century
# 208                            A Brief History of Time
# 232                          The Diary of a Young Girl
# 234                                              Paula
# 276                              Beneath the Sugar Sky
# 322  The Man Who Loved Books Too Much: The True Sto...
# 385  Atomic Habits: An Easy & Proven Way to Build G...
# 424                                            My Body
# 433         I Want to Die but I Want to Eat Tteokbokki
# 452                           Man's Search for Meaning
# 464                                 Frumoasele străine
# 580                                     Milk and Honey
# 616                     Snow Flower and the Secret Fan
# 784                         We Should All Be Feminists
#
#                       Authors  \
# 68              Carlo Rovelli
# 176           Stephen Hawking
# 203         Yuval Noah Harari
# 208           Stephen Hawking
# 232                Anne Frank
# 234            Isabel Allende
# 276            Seanan McGuire
# 322   Allison Hoover Bartlett
# 385               James Clear
# 424         Emily Ratajkowski
# 433               Baek Se-hee
# 452          Viktor E. Frankl
# 464         Mircea Cărtărescu
# 580                 Rupi Kaur
# 616                  Lisa See
# 784  Chimamanda Ngozi Adichie
#
#                                           Contributors Read Status  \
# 68                                             Missing        read
# 176                                            Missing        read
# 203                                            Missing        read
# 208                                            Missing        read
# 232               B.M. Mooyaart-Doubleday (Translator)        read
# 234                              Margaret Sayers Peden        read
# 276                                            Missing        read
# 322                                            Missing        read
# 385                                            Missing        read
# 424                                            Missing        read
# 433                             Anton Hur (Translator)        read
# 452  Harold S. Kushner (Contributor), William J. Wi...        read
# 464                                            Missing        read
# 580                                            Missing        read
# 616                                            Missing        read
# 784                                            Missing        read
#
#     Last Date Read    Moods    Pace Character- or Plot-Driven?  \
# 68      2022-07-18  Missing     NaN                        NaN
# 176     2019-01-01  Missing     NaN                        NaN
# 203     2022-05-31  Missing     NaN                        NaN
# 208     2020-08-30  Missing     NaN                        NaN
# 232     2018-01-01  Missing     NaN                        NaN
# 234     2018-01-01  Missing     NaN                        NaN
# 276     2019-01-01  Missing    fast                      A mix
# 322     2018-01-01  Missing     NaN                        NaN
# 385     2022-06-01  Missing     NaN                        NaN
# 424     2022-04-15  Missing     NaN                        NaN
# 433     2022-07-29  Missing     NaN                        NaN
# 452     2019-01-01  Missing     NaN                        NaN
# 464     2018-01-01  Missing  medium                      A mix
# 580     2019-01-01  Missing     NaN                        NaN
# 616     2018-01-01  Missing  medium                  Character
# 784     2022-04-13  Missing     NaN                        NaN
#
#     Strong Character Development? Loveable Characters? Diverse Characters?  \
# 68                            NaN                  NaN                 NaN
# 176                           NaN                  NaN                 NaN
# 203                           NaN                  NaN                 NaN
# 208                           NaN                  NaN                 NaN
# 232                           NaN                  NaN                 NaN
# 234                           NaN                  NaN                 NaN
# 276                           Yes                  Yes                 Yes
# 322                           NaN                  NaN                 NaN
# 385                           NaN                  NaN                 NaN
# 424                           NaN                  NaN                 NaN
# 433                           NaN                  NaN                 NaN
# 452                           NaN                  NaN                 NaN
# 464                            No     It's complicated                  No
# 580                           NaN                  NaN                 NaN
# 616                           Yes     It's complicated    It's complicated
# 784                           NaN                  NaN                 NaN
#
#     Flawed Characters?  Star Rating  \
# 68                 NaN          NaN
# 176                NaN          NaN
# 203                NaN          NaN
# 208                NaN          NaN
# 232                NaN          NaN
# 234                NaN          NaN
# 276                Yes          4.5
# 322                NaN          NaN
# 385                NaN          NaN
# 424                NaN          NaN
# 433                NaN          NaN
# 452                NaN          NaN
# 464                 No          2.0
# 580                NaN          4.0
# 616                Yes          4.0
# 784                NaN          NaN
#
#                                             Tags
# 68           informative, nonfiction, slow-paced
# 176                                          NaN
# 203                                          NaN
# 208                                          NaN
# 232                                          NaN
# 234                                          NaN
# 276      fantasy, short, adventurous, fast-paced
# 322                                          NaN
# 385                                          NaN
# 424                                          NaN
# 433         medium-paced, nonfiction, reflective
# 452                                          NaN
# 464    funny, medium-paced, contemporary, medium
# 580                            emotional, medium
# 616  medium-paced, emotional, historical, medium
# 784                                          NaN

# %%
read.loc[276, 'Moods'] = 'adventurous'
read.loc[464, 'Moods'] = 'reflective'
read.loc[616, 'Moods'] = 'emotional'

# %% [markdown]
# Most of these are nonfiction books that don't even have a rating. Given the fact that we can't exacly talk about character
# development or lovable characters in this case, I'll drop most of these. I'll keep those that are fiction and rated, and replace
# the missing mood values with the appropriate moods.

# %%
read.drop(read[read['Moods'] == 'Missing'].index, inplace=True)

# %%
read.loc[read['Character- or Plot-Driven?'].isnull()]
# Out:
#                                                  Title             Authors  \
# 57                              Beyond the Aquila Rift   Alastair Reynolds
# 62                                             Șarpele       Mircea Eliade
# 119                                       Hanu-Ancuței    Mihail Sadoveanu
# 159                                              Iubim       Octav Dessila
# 196                            The Sun and Her Flowers           Rupi Kaur
# 302                   Two on a Tower (English Edition)        Thomas Hardy
# 369               Stung with Love: Poems and Fragments              Sappho
# 407                                   Viata ca o prada         Marin Preda
# 419                                    Aripi de zapada  Constantin Chiriță
# 466                                    LA BIBLE PERDUE        Igor Bergler
# 542                            Letters to a Young Poet  Rainer Maria Rilke
# 555                                      The Symposium               Plato
# 571                                  Orasul cu salcami    Mihail Sebastian
# 594                                         La Țigănci       Mircea Eliade
# 613                                           Papillon     Henri Charrière
# 763  Ultima noapte de dragoste întâia noapte de război      Camil Petrescu
#
#                                           Contributors Read Status  \
# 57                                          Tom Dheere        read
# 62                                             Missing        read
# 119                                            Missing        read
# 159                                            Missing        read
# 196                                            Missing        read
# 302                                            Missing        read
# 369  Carol Ann Duffy (Contributor), Aaron Poochigia...        read
# 407                                            Missing        read
# 419                                            Missing        read
# 466                                            Missing        read
# 542                        Reginald Snell (Translator)        read
# 555                      Christopher Gill (Translator)        read
# 571                                            Missing        read
# 594                                            Missing        read
# 613                                            Missing        read
# 763                                            Missing        read
#
#     Last Date Read        Moods    Pace Character- or Plot-Driven?  \
# 57      2021-01-01         dark    fast                        NaN
# 62      2018-01-01   reflective  medium                        NaN
# 119     2018-01-01  adventurous  medium                        NaN
# 159     2018-01-01    emotional    slow                        NaN
# 196     2019-01-01    emotional  medium                        NaN
# 302     2018-01-01    emotional  medium                        NaN
# 369     2021-02-12   reflective  medium                        NaN
# 407     2018-01-01   reflective  medium                        NaN
# 419     2018-01-01  adventurous  medium                        NaN
# 466     2018-01-01   mysterious  medium                        NaN
# 542     2021-05-12   reflective    slow                        NaN
# 555     2021-02-11   reflective  medium                        NaN
# 571     2018-01-01   reflective  medium                        NaN
# 594     2018-01-01   mysterious  medium                        NaN
# 613     2018-01-01  adventurous  medium                        NaN
# 763     2018-01-01   reflective  medium                        NaN
#
#     Strong Character Development? Loveable Characters? Diverse Characters?  \
# 57                            NaN                  NaN                 NaN
# 62                            NaN                  NaN                 NaN
# 119                           NaN                  NaN                 NaN
# 159                           NaN                  NaN                 NaN
# 196                           NaN                  NaN                 NaN
# 302                           NaN                  NaN                 NaN
# 369                           NaN                  NaN                 NaN
# 407                           NaN                  NaN                 NaN
# 419                           NaN                  NaN                 NaN
# 466                           NaN                  NaN                 NaN
# 542                           NaN                  NaN                 NaN
# 555                           NaN                  NaN                 NaN
# 571                           NaN                  NaN                 NaN
# 594                           NaN                  NaN                 NaN
# 613                           NaN                  NaN                 NaN
# 763                           NaN                  NaN                 NaN
#
#     Flawed Characters?  Star Rating  \
# 57                 NaN         4.00
# 62                 NaN         3.00
# 119                NaN         1.00
# 159                NaN         4.25
# 196                NaN         3.00
# 302                NaN         1.00
# 369                NaN         3.75
# 407                NaN         1.00
# 419                NaN         4.50
# 466                NaN         3.50
# 542                NaN         3.50
# 555                NaN         3.75
# 571                NaN         3.00
# 594                NaN         3.50
# 613                NaN         4.50
# 763                NaN         3.00
#
#                                             Tags
# 57               dark, short, sci-fi, fast-paced
# 62     classics, short, medium-paced, reflective
# 119  classics, medium-paced, adventurous, medium
# 159        emotional, slow-paced, long, literary
# 196                            emotional, medium
# 302     medium-paced, emotional, medium, romance
# 369                  classics, short, reflective
# 407   classics, medium-paced, reflective, medium
# 419  classics, medium-paced, adventurous, medium
# 466     mysterious, thriller, medium-paced, long
# 542                  classics, short, reflective
# 555    classics, short, medium-paced, reflective
# 571   classics, medium-paced, reflective, medium
# 594    classics, mysterious, short, medium-paced
# 613    classics, medium-paced, adventurous, long
# 763   classics, medium-paced, reflective, medium

# %% [markdown]
# I can't drop these ones because they're important so I'll try to replace them using SimpleImputer from sklearn. There are 2
# nonfiction books here too: Letters to a young poet and The Symposium, plus two books of poetry. I thought about dropping
# these as well, but they have been rated and these ones felt almost like fiction(they can be considered classics), so I've
# decided to keep them.

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
read.iloc[:, 7:12] = imputer.fit_transform(read.iloc[:, 7:12])

# %% [markdown]
# After imputing null values, I want to take a look at the lowest rated ones. One thing all of my lowest rated books have in
# common is the fact that I didn't like the characters, so I want to make sure that all of them have 'No' as answer for
# 'Loveable Characters?'

# %%
read.loc[119, 'Loveable Characters?'] = 'No'
read.loc[302, 'Loveable Characters?'] = 'No'
read.loc[407, 'Loveable Characters?'] = 'No'

# %% [markdown]
# Next I want to take a look at the 'Tags' column and separate it.

# %%
from collections import Counter
check = Counter()
for i in read['Tags']:
    check.update(i.split(','))
descriptions = dict(check)
descriptions
# Out:
# {'mysterious': 34,
#  ' slow-paced': 99,
#  ' long': 74,
#  ' literary': 16,
#  'medium-paced': 67,
#  ' sci-fi': 56,
#  ' adventurous': 160,
#  ' emotional': 65,
#  ' medium': 287,
#  'fantasy': 115,
#  ' medium-paced': 183,
#  ' contemporary': 38,
#  'sci-fi': 21,
#  ' fast-paced': 98,
#  ' historical': 24,
#  'classics': 112,
#  ' short': 63,
#  ' reflective': 58,
#  'dark': 47,
#  'emotional': 4,
#  ' fantasy': 7,
#  ' thriller': 11,
#  'short': 26,
#  'funny': 7,
#  ' horror': 27,
#  ' lighthearted': 7,
#  ' tense': 5,
#  ' mysterious': 8,
#  ' dark': 29,
#  ' funny': 9,
#  ' hopeful': 5,
#  ' romance': 8,
#  ' sad': 4,
#  'reflective': 3,
#  ' challenging': 2,
#  'contemporary': 5,
#  'historical': 2,
#  ' informative': 2,
#  'thriller': 6,
#  ' graphic-novel': 1,
#  'adventurous': 1}

# %% [markdown]
# Checking for whitespace, which most of them seem to have.

# %%
t = read['Tags'].str.split(',', expand=True)
t
# Out:
#                 0              1              2              3
# 2      mysterious     slow-paced           long       literary
# 3    medium-paced         sci-fi    adventurous           long
# 5    medium-paced      emotional         medium       literary
# 9         fantasy   medium-paced    adventurous         medium
# 10   medium-paced   contemporary      emotional         medium
# ..            ...            ...            ...            ...
# 820    mysterious       thriller   medium-paced         medium
# 823      classics     mysterious          short   medium-paced
# 825          dark   medium-paced         horror         medium
# 826       fantasy           dark          short     fast-paced
# 830      classics      emotional     slow-paced         medium
#
# [450 rows x 4 columns]

# %%
t.rename(columns = {0: 'sizes', 1: 'genre', 2: 'tone', 3: 'pace'}, inplace=True)
t
# Out:
#             sizes          genre           tone           pace
# 2      mysterious     slow-paced           long       literary
# 3    medium-paced         sci-fi    adventurous           long
# 5    medium-paced      emotional         medium       literary
# 9         fantasy   medium-paced    adventurous         medium
# 10   medium-paced   contemporary      emotional         medium
# ..            ...            ...            ...            ...
# 820    mysterious       thriller   medium-paced         medium
# 823      classics     mysterious          short   medium-paced
# 825          dark   medium-paced         horror         medium
# 826       fantasy           dark          short     fast-paced
# 830      classics      emotional     slow-paced         medium
#
# [450 rows x 4 columns]

# %%
t['sizes'] = t['sizes'].str.strip()
t['genre'] = t['genre'].str.strip()
t['tone'] = t['tone'].str.strip()
t['pace'] = t['pace'].str.strip()

# %% [markdown]
# Moving the values so they correspond to their column names. The first two columns are important, the other 2 contain values
# that are already present in the dataset.

# %%
t['c_sizes'] = t['sizes']

# %%
s = ['short', 'long', 'medium']
g = ['classics', 'contemporary', 'fantasy', 'historical', 'horror', 'literary', 'romance', 'sci-fi', 'thriller']

t['sizes'] = np.where(t['genre'].isin(s), t['genre'], t['sizes'])
t['sizes'] = np.where(t['tone'].isin(s), t['tone'], t['sizes'])
t['sizes'] = np.where(t['pace'].isin(s), t['pace'], t['sizes'])

t['genre'] = np.where(t['tone'].isin(g), t['tone'], t['genre'])
t['genre'] = np.where(t['pace'].isin(g), t['pace'], t['genre'])
t['genre'] = np.where(t['c_sizes'].isin(g), t['c_sizes'], t['genre'])


t
# Out:
#       sizes         genre          tone          pace       c_sizes
# 2      long      literary          long      literary    mysterious
# 3      long        sci-fi   adventurous          long  medium-paced
# 5    medium      literary        medium      literary  medium-paced
# 9    medium       fantasy   adventurous        medium       fantasy
# 10   medium  contemporary     emotional        medium  medium-paced
# ..      ...           ...           ...           ...           ...
# 820  medium      thriller  medium-paced        medium    mysterious
# 823   short      classics         short  medium-paced      classics
# 825  medium        horror        horror        medium          dark
# 826   short       fantasy         short    fast-paced       fantasy
# 830  medium      classics    slow-paced        medium      classics
#
# [450 rows x 5 columns]

# %%
t['sizes'].value_counts()
# Out:
# medium    287
# short      89
# long       74
# Name: sizes, dtype: int64

# %%
t['genre'].value_counts()
# Out:
# fantasy          122
# classics         112
# sci-fi            77
# contemporary      43
# horror            27
# historical        26
# thriller          17
# literary          16
# romance            8
# graphic-novel      1
# medium             1
# Name: genre, dtype: int64

# %% [markdown]
# There is still a value of 'medium' and one of 'graphic-novel', which need to be dealt with, but first I'll drop the unnecessary
# columns and combine the other ones with the 'read' dataframe.

# %%
t.drop(['c_sizes', 'tone', 'pace'], axis=1, inplace=True)

# %%
read.reset_index(drop=True, inplace=True)
t.reset_index(drop=True, inplace=True)
final = pd.concat( [read, t], axis=1) 
final.drop(['Tags'], axis=1, inplace=True)

# %%
final
# Out:
#                                Title           Authors Contributors  \
# 0         The Wind-Up Bird Chronicle   Haruki Murakami    Jay Rubin
# 1                           The Toll   Neal Shusterman      Missing
# 2               Transcendent Kingdom         Yaa Gyasi      Missing
# 3                        Hollow City      Ransom Riggs      Missing
# 4     The Astonishing Color of After    Emily X.R. Pan      Missing
# ..                               ...               ...          ...
# 445                    Truly Devious   Maureen Johnson      Missing
# 446             Domniṣoara Christina     Mircea Eliade      Missing
# 447           Into the Drowning Deep        Mira Grant      Missing
# 448  Down Among the Sticks and Bones    Seanan McGuire      Missing
# 449                   Enigma Otiliei  George Călinescu      Missing
#
#     Read Status Last Date Read        Moods    Pace  \
# 0          read     2018-01-01   reflective    slow
# 1          read     2019-12-04  adventurous  medium
# 2          read     2022-04-10    emotional  medium
# 3          read     2020-03-05  adventurous  medium
# 4          read     2020-01-20    emotional  medium
# ..          ...            ...          ...     ...
# 445        read     2020-03-02   mysterious  medium
# 446        read     2018-01-01   mysterious  medium
# 447        read     2019-01-01         dark  medium
# 448        read     2019-01-01         dark    fast
# 449        read     2018-01-01    emotional    slow
#
#     Character- or Plot-Driven? Strong Character Development?  \
# 0                    Character                            No
# 1                        A mix                           Yes
# 2                    Character                           Yes
# 3                        A mix                           Yes
# 4                    Character                           Yes
# ..                         ...                           ...
# 445                       Plot                           Yes
# 446                       Plot                            No
# 447                       Plot                           Yes
# 448                      A mix                           Yes
# 449                  Character              It's complicated
#
#     Loveable Characters? Diverse Characters? Flawed Characters?  Star Rating  \
# 0       It's complicated                  No   It's complicated         2.50
# 1                    Yes                 Yes                Yes         4.00
# 2                    Yes                 Yes                Yes         4.00
# 3                    Yes                 Yes                 No         3.75
# 4                    Yes                 Yes                Yes         4.50
# ..                   ...                 ...                ...          ...
# 445     It's complicated                 Yes                Yes         3.00
# 446     It's complicated                  No                 No         4.00
# 447                  Yes                 Yes                 No         3.75
# 448                  Yes                 Yes                Yes         5.00
# 449     It's complicated                  No                Yes         3.50
#
#       sizes         genre
# 0      long      literary
# 1      long        sci-fi
# 2    medium      literary
# 3    medium       fantasy
# 4    medium  contemporary
# ..      ...           ...
# 445  medium      thriller
# 446   short      classics
# 447  medium        horror
# 448   short       fantasy
# 449  medium      classics
#
# [450 rows x 15 columns]

# %% [markdown]
# Rearranging the columns.

# %%
final = final[['Title', 'Authors', 'Contributors', 'Read Status', 'Last Date Read', 'Moods', 'Pace', 
               'Character- or Plot-Driven?','Strong Character Development?', 'Loveable Characters?', 'Diverse Characters?',
               'Flawed Characters?', 'sizes', 'genre', 'Star Rating']]
final.loc[final['genre'] == 'medium']
# Out:
#                       Title    Authors Contributors Read Status  \
# 96  The Sun and Her Flowers  Rupi Kaur      Missing        read
#
#    Last Date Read      Moods    Pace Character- or Plot-Driven?  \
# 96     2019-01-01  emotional  medium                      A mix
#
#    Strong Character Development? Loveable Characters? Diverse Characters?  \
# 96                           Yes                  Yes                  No
#
#    Flawed Characters?   sizes   genre  Star Rating
# 96                Yes  medium  medium          3.0

# %%
final.loc[96, 'genre'] = 'contemporary'
final.loc[final['genre'] == 'graphic-novel']
# Out:
#                                         Title          Authors Contributors  \
# 272  The Boy, the Mole, the Fox and the Horse  Charlie Mackesy      Missing
#
#     Read Status Last Date Read    Moods  Pace Character- or Plot-Driven?  \
# 272        read     2021-01-24  hopeful  fast                  Character
#
#     Strong Character Development? Loveable Characters? Diverse Characters?  \
# 272              It's complicated                  Yes    It's complicated
#
#     Flawed Characters?  sizes          genre  Star Rating
# 272                 No  short  graphic-novel          4.5

# %%
final.loc[272, 'genre'] = 'contemporary'

# %%
final.isnull().sum()
# Out:
# Title                            0
# Authors                          0
# Contributors                     0
# Read Status                      0
# Last Date Read                   0
# Moods                            0
# Pace                             0
# Character- or Plot-Driven?       0
# Strong Character Development?    0
# Loveable Characters?             0
# Diverse Characters?              0
# Flawed Characters?               0
# sizes                            0
# genre                            0
# Star Rating                      0
# dtype: int64

# %%
final.to_csv('final.csv')
